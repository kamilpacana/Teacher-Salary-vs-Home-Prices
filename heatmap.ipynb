# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import geopandas

# %%
con = sqlite3.connect('boston_employee_data.db')

query = "select * from yearly_earnings"

wages = pd.read_sql_query(query, con)
avg_wage_2012 = wages.average_earnings[wages.year == '2012'][1]

# %%
con2 = sqlite3.connect('boston_prop_data.db')

query2 = "select * from cleaned_prop_22"

prop = pd.read_sql_query(query2, con2)
prop.iloc[59]
# Out:
# ST_NUM             175
# ST_NAME        BEACON ST
# CITY              BOSTON
# TOTAL_VALUE    8242000.0
# Name: 59, dtype: object

# %%
address_list = list()
for i in range(len(prop)):
    address = f'{prop.ST_NUM[i]} {prop.ST_NAME[i]}, {prop.CITY[i]}, MA'
    location = geolocator.geocode(address)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~\anaconda3\envs\geo\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~\anaconda3\envs\geo\lib\site-packages\urllib3\connection.py:454, in HTTPConnection.getresponse(self)
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#
# File ~\anaconda3\envs\geo\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# ...

# %%
from geopy.geocoders import Nominatim

# Create a geocoder object
geolocator = Nominatim(user_agent="my_geocoder", timeout=10)

lat_list = list()
long_list = list()

# Example street address
for i in range(len(prop)):
    address = f'{prop.ST_NUM[i]} {prop.ST_NAME[i]}, {prop.CITY[i]}, MA'
    
    location = geolocator.geocode(address)
    
    if str(type(location)) == "<class 'geopy.location.Location'>":
        
        # Extract latitude and longitude from the location object
        latitude = float(location.latitude)
        longitude = float(location.longitude)

        lat_list.append(latitude)
        long_list.append(longitude)

'''bos_map = np.zeros((1000,1000), dtype=int)

# standardizing lat and long data to convert it to numpy array and scaling it to fit 1000x1000 frame
for row in range(len(trees)):
    long = int(((trees[row][0] - -70.9) / (-70.9 - -71.2)) * 999) 
    lat = int(((42.4 - trees[row][1]) / (42.4 - 42.2)) * 999)
    
    # marking every area there is a tree on the map
    bos_map[lat][long] = 1

# plotting array data and assigning correct labels and title
plt.imshow(bos_map, cmap = 'inferno')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Tree Map of Boston')
plt.savefig('tree_map_AE.png', bbox_inches = 'tight')
plt.show()'''

lat_list.length()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[90], line 13
#      10 for i in range(len(prop)):
#      11     address = f'{prop.ST_NUM[i]} {prop.ST_NAME[i]}, {prop.CITY[i]}, MA'
# ---> 13     location = geolocator.geocode(address)
#      15     if str(type(location)) == "<class 'geopy.location.Location'>":
#      16
#      17         # Extract latitude and longitude from the location object
#      18         latitude = float(location.latitude)
#
# File ~\anaconda3\envs\geo\lib\site-packages\geopy\geocoders\nominatim.py:297, in Nominatim.geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     295 logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     296 callback = partial(self._parse_json, exactly_one=exactly_one)
# ...

# %%
for i in range(5):
    address = f'{prop.ST_NUM[i]} {prop.ST_NAME[i]}, {prop.CITY[i]}, MA'
    print(address)
# Out:
# 25  EXETER ST, BOSTON, MA
# 5  COMMONWEALTH AV, BOSTON, MA
# 15  COMMONWEALTH AV, BOSTON, MA
# 315  DARTMOUTH ST, BOSTON, MA
# 19  LOUISBURG SQ, BOSTON, MA

# %%
address = f'{prop.ST_NUM[15]} {prop.ST_NAME[16]}, {prop.CITY[5]}, MA'
print(address)
'''has_null = prop.iloc[i].isnull().any()

if has_null:
print(f'{i} contains null values')
'''    
# Geocode the address to retrieve the coordinates
location = geolocator.geocode(address)
print(str(type(location)))
if str(type(location)) == "<class 'geopy.location.Location'>":
    print('hi')
# Out:
# 20   LOUISBURG SQ, BOSTON, MA
# <class 'geopy.location.Location'>
# hi
